# %%
# prompt: import pandas as pd

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import preprocessing

# %%
data = pd.read_csv('/content/creditcard.csv')

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 43659  41598 -0.538686 -0.635328 -0.041569 -3.022158  0.771776  3.556774
# 43660  41599 -0.349615 -2.860571  0.297766  0.801212 -1.523995  1.164260
# 43661  41599 -3.001222  2.899766  0.726874 -0.729992 -0.312792 -0.735557
# 43662  41599  1.042342 -0.390001 -0.463680 -1.737393  0.450611  0.604354
# 43663  41600  1.193909  0.067328  0.609239  0.825453 -0.332038 -0.101522
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 43659 -1.418820  1.371999 -2.475053  ... -0.090409 -0.310254  0.168510
# 43660  0.037484  0.325220  0.862825  ...  0.315370 -0.503099 -0.514747
# 43661  0.960944 -0.276141  2.128747  ... -0.645540 -0.613956  0.111663
# 43662  0.068099  0.278030  0.555053  ... -0.137137 -0.286887  0.143336
# 43663 -0.130782 -0.033697  0.424588  ... -0.049950  0.213908 -0.068750
#
#             V24       V25       V26       V27       V28  Amount  Class
# 43659  0.955413 -0.427495 -0.375891  0.051010  0.072416   60.01    0.0
# 43660 -0.193890 -0.327091  0.875820 -0.144908  0.125368  745.56    0.0
# 43661  0.338567  0.268357  0.076981  1.184716  0.491066    8.99    0.0
# 43662 -0.986810  0.135599 -0.185344  0.035590 -0.008304   48.00    0.0
# 43663  0.182281  0.557841  0.400000       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43664 entries, 0 to 43663
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    43664 non-null  int64
#  1   V1      43664 non-null  float64
#  2   V2      43664 non-null  float64
#  3   V3      43664 non-null  float64
#  4   V4      43664 non-null  float64
#  5   V5      43664 non-null  float64
#  6   V6      43664 non-null  float64
#  7   V7      43664 non-null  float64
#  8   V8      43664 non-null  float64
#  9   V9      43664 non-null  float64
#  10  V10     43664 non-null  float64
#  11  V11     43664 non-null  float64
#  12  V12     43664 non-null  float64
#  13  V13     43664 non-null  float64
#  14  V14     43664 non-null  float64
#  15  V15     43664 non-null  float64
#  16  V16     43664 non-null  float64
#  17  V17     43664 non-null  float64
#  18  V18     43664 non-null  float64
#  19  V19     43664 non-null  float64
#  20  V20     43664 non-null  float64
#  21  V21     43664 non-null  float64
#  22  V22     43664 non-null  float64
#  23  V23     43664 non-null  float64
#  24  V24     43664 non-null  float64
#  25  V25     43664 non-null  float64
#  26  V26     43664 non-null  float64
#  27  V27     43663 non-null  float64
#  28  V28     43663 non-null  float64
#  29  Amount  43663 non-null  float64
#  30  Class   43663 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 10.3 MB

# %%
data.isnull()
# Out:
#         Time     V1     V2     V3     V4     V5     V6     V7     V8     V9  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 43659  False  False  False  False  False  False  False  False  False  False
# 43660  False  False  False  False  False  False  False  False  False  False
# 43661  False  False  False  False  False  False  False  False  False  False
# 43662  False  False  False  False  False  False  False  False  False  False
# 43663  False  False  False  False  False  False  False  False  False  False
#
#        ...    V21    V22    V23    V24    V25    V26    V27    V28  Amount  \
# 0      ...  False  False  False  False  False  False  False  False   False
# 1      ...  False  False  False  False  False  False  False  False   False
# 2      ...  False  False  False  False  False  False  False  False   False
# 3      ...  False  False  False  False  False  False  False  False   False
# 4      ...  False  False  False  False  False  False  False  False   False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...     ...
# 43659  ...  False  False  False  False  False  False  False  False   False
# 43660  ...  False  False  False  False  False  False  False  False   False
# 43661  ...  False  False  False  False  False  False  False  False   False
# 43662  ...  False  False  False  False  False  False  False  False   False
# 43663  ...  False  False  False  False  False  False   True   True    True
#
#        Class
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 43659  False
# 43660  False
# 43661  False
# 43662  False
# 43663   True
#
# [43664 rows x 31 columns]

# %%
data['Class'].value_counts()
# Out:
# Class
# 0.0    43529
# 1.0      134
# Name: count, dtype: int64

# %%
legit=data[data.Class == 0]
fraud =data[data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (43529, 31)
# (134, 31)

# %%
legit.Amount.describe()
# Out:
# count    43529.000000
# mean        90.302800
# std        238.465356
# min          0.000000
# 25%          7.580000
# 50%         24.900000
# 75%         81.400000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     134.000000
# mean       93.928433
# std       231.551248
# min         0.000000
# 25%         1.000000
# 50%         6.455000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    26892.929610 -0.210136  0.014404   0.735522  0.173494 -0.226584
# 1.0    25259.246269 -7.759814  5.619386 -10.672832  6.111351 -5.776140
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.106817 -0.092752  0.039222  0.185126  ...  0.046501 -0.029740
# 1.0   -2.360976 -8.192938  4.040000 -3.571525  ...  0.507150  0.931331
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.109589 -0.039132  0.010036  0.135999  0.022175  0.004776  0.004927
# 1.0   -0.270332 -0.315606 -0.096976  0.279383  0.168436  0.687503  0.063472
#
#           Amount
# Class
# 0.0    90.302800
# 1.0    93.928433
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=134)

# %%
new = pd.concat([legit_sample,fraud],axis=0)

# %%
new.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 40131  40108  1.185378  0.156129 -0.091792  0.832892  0.159289 -0.135990
# 34129  37525 -1.080516 -0.089445  2.686930  1.438936 -0.270145  1.618983
# 39949  40033 -2.351496  2.414298 -0.317356 -0.146747 -0.126651  2.580715
# 20394  31010 -0.204149  0.935040  0.797376  0.968054  0.431777  0.341473
# 28812  35175  0.907078 -0.700137  0.989079  0.604055 -1.160629 -0.099307
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 40131  0.141740 -0.034361 -0.204427  ...  0.045041  0.049043 -0.252053
# 34129 -0.295568  0.704654  0.104925  ...  0.350813  1.127164 -0.112101
# 39949 -3.350279 -7.043899 -1.151947  ... -3.744894  1.558198  0.276639
# 20394  0.636392  0.021289 -0.414404  ...  0.201135  0.641421 -0.158038
# 28812 -0.586388  0.049830  0.751560  ...  0.290126  0.518257 -0.241198
#
#             V24       V25       V26       V27       V28  Amount  Class
# 40131 -0.524015  0.754379 -0.296038  0.000490  0.008085   44.17    0.0
# 34129 -0.239413  0.334043  0.106163  0.130765  0.084187  100.00    0.0
# 39949 -1.306145 -0.218183  0.406069  0.168805  0.216910   29.03    0.0
# 20394 -0.770641 -0.552354 -0.212614  0.116924  0.169902   40.00    0.0
# 28812 -0.049435  0.195847  0.589635 -0.018086  0.055404  175.60    0.0
#
# [5 rows x 31 columns]

# %%
new['Class'].value_counts()
# Out:
# Class
# 0.0    134
# 1.0    134
# Name: count, dtype: int64

# %%
X=new.drop(columns='Class', axis=1)
Y=new['Class']

# %%
print(X)
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 40131  40108   1.185378  0.156129  -0.091792  0.832892   0.159289 -0.135990
# 34129  37525  -1.080516 -0.089445   2.686930  1.438936  -0.270145  1.618983
# 39949  40033  -2.351496  2.414298  -0.317356 -0.146747  -0.126651  2.580715
# 20394  31010  -0.204149  0.935040   0.797376  0.968054   0.431777  0.341473
# 28812  35175   0.907078 -0.700137   0.989079  0.604055  -1.160629 -0.099307
# ...      ...        ...       ...        ...       ...        ...       ...
# 43061  41353 -15.020981  8.075240 -16.298091  5.664820 -11.918153 -4.246957
# 43160  41397 -14.970346  8.401421 -16.867238  8.252334 -13.565130 -2.782438
# 43204  41413 -15.140450  7.378042 -16.356367  9.194935 -13.466163 -2.958431
# 43428  41505 -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 43624  41582  -1.048005  1.300219  -0.180401  2.589843  -1.164794  0.031823
#
#               V7         V8        V9  ...       V20       V21       V22  \
# 40131   0.141740  -0.034361 -0.204427  ... -0.031399  0.045041  0.049043
# 34129  -0.295568   0.704654  0.104925  ...  0.273465  0.350813  1.127164
# 39949  -3.350279  -7.043899 -1.151947  ...  1.934599 -3.744894  1.558198
# 20394   0.636392   0.021289 -0.414404  ... -0.053362  0.201135  0.641421
# 28812  -0.586388   0.049830  0.751560  ...  0.301262  0.290126  0.518257
# ...          ...        ...       ...  ...       ...       ...       ...
# 43061 -14.716668   9.435084 -6.795398  ... -0.995787  2.525115 -0.832074
# 43160 -14.263735   9.643419 -7.701499  ... -1.614660  2.714045 -0.101355
# 43204 -16.165539  10.075254 -7.901821  ... -1.691482  3.147428  0.341678
# 43428 -16.701694   7.517344 -8.507059  ... -1.514923  1.190739 -1.127670
# 43624  -2.175778   0.699072 -1.140208  ...  0.644993  0.549014  0.624321
#
#             V23       V24       V25       V26       V27       V28  Amount
# 40131 -0.252053 -0.524015  0.754379 -0.296038  0.000490  0.008085   44.17
# 34129 -0.112101 -0.239413  0.334043  0.106163  0.130765  0.084187  100.00
# 39949  0.276639 -1.306145 -0.218183  0.406069  0.168805  0.216910   29.03
# 20394 -0.158038 -0.770641 -0.552354 -0.212614  0.116924  0.169902   40.00
# 28812 -0.241198 -0.049435  0.195847  0.589635 -0.018086  0.055404  175.60
# ...         ...       ...       ...       ...       ...       ...     ...
# 43061 -0.186117  0.429781  0.697103  0.056031 -1.310888 -0.707403   34.12
# 43160 -0.439666  0.519514  0.789328  0.064357 -1.621386 -1.104819  273.01
# 43204 -1.150162  0.795190 -0.194542  0.145964 -2.458680 -1.189888  106.55
# 43428 -2.358579  0.673461 -1.413700 -0.462762 -2.018575 -1.042804  364.19
# 43624 -0.136663  0.131738  0.030921 -0.176701  0.504898  0.069882   39.45
#
# [268 rows x 30 columns]

# %%
print(Y)
# Out:
# 40131    0.0
# 34129    0.0
# 39949    0.0
# 20394    0.0
# 28812    0.0
#         ...
# 43061    1.0
# 43160    1.0
# 43204    1.0
# 43428    1.0
# 43624    1.0
# Name: Class, Length: 268, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify= Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (268, 30) (214, 30) (54, 30)

# %%
model = LogisticRegression(max_iter=1000)

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
pred=model.predict(X_train)
acc=accuracy_score(pred,Y_train)

# %%
print(acc)
# Out:
# 0.9906542056074766

# %%
test_pred = model.predict(X_test)
test_acc = accuracy_score(test_pred,Y_test)

# %%
print(test_acc)
# Out:
# 0.9444444444444444
